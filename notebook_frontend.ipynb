# %%
# %matplotlib notebook

# %%
import widgets

# %%
widgets.expected_damage()
# Out:
# <img src="data:image/png;base64,..." width="800">
# aW50ZXJhY3RpdmUoY2hpbGRyZW49KEludFNsaWRlcih2YWx1ZT0wLCBkZXNjcmlwdGlvbj11J2RleCcsIG1heD0xMCwgbWluPS0xMCksIEludFNsaWRlcih2YWx1ZT0xMCwgZGVzY3JpcHRpb27igKY=
# <function widgets.update>

# %%
widgets.distribution()
# Out:
# aW50ZXJhY3RpdmUoY2hpbGRyZW49KEludFNsaWRlcih2YWx1ZT0wLCBkZXNjcmlwdGlvbj11J2RleCcsIG1heD0xMCwgbWluPS0xMCksIEludFNsaWRlcih2YWx1ZT0xMCwgZGVzY3JpcHRpb27igKY=
# <function widgets.update>
