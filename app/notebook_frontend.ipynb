# %%
# %matplotlib notebook

# %%
show = ['Fire Bolt', 'Toll the Dead', 'Magic Missile', 'Chromatic Orb', 'Thunderwave', 'Hellish Rebuke', 
        'Fire Ball', 'Melf\'s Minute Meteors', 'Blight', 'Ice Storm', 'Phantasmal Killer', 'Black Tentacles',
        'Vitriolic Sphere', 'Storm Sphere']

# %%
import engine.widgets

# %%
engine.widgets.expected_damage(rotate=True, figsize=(10,8), ylim=40, show=show)
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
# aW50ZXJhY3RpdmUoY2hpbGRyZW49KEludFNsaWRlcih2YWx1ZT0wLCBkZXNjcmlwdGlvbj11J2RleCcsIG1heD0xMCwgbWluPS0xMCksIEludFNsaWRlcih2YWx1ZT0wLCBkZXNjcmlwdGlvbj3igKY=
# <function engine.widgets.update>

# %%
engine.widgets.distribution(show=['Magic Missile', "Chromatic Orb"])
# Out:
# aW50ZXJhY3RpdmUoY2hpbGRyZW49KEludFNsaWRlcih2YWx1ZT0wLCBkZXNjcmlwdGlvbj11J2RleCcsIG1heD0xMCwgbWluPS0xMCksIEludFNsaWRlcih2YWx1ZT0wLCBkZXNjcmlwdGlvbj3igKY=
# <function engine.widgets.update>
