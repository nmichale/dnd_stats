# %%
# %matplotlib notebook

# %%
# from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
show = ['Fire Bolt', 'Chromatic Orb', 'Magic Missile', 'Thunderwave', 'Hellish Rebuke', 'Fire Ball', 'Melf\'s Minute Meteors']

# %%
import engine.widgets

# %%
engine.widgets.expected_damage(rotate=True, figsize=(10,8), ylim=40, show=show)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Fire Bolt
# Chromatic Orb
# Magic Missile
# Thunderwave
# Hellish Rebuke
# Fire Ball
# Melf's Minute Meteors
# aW50ZXJhY3RpdmUoY2hpbGRyZW49KEludFNsaWRlcih2YWx1ZT0wLCBkZXNjcmlwdGlvbj11J2RleCcsIG1heD0xMCwgbWluPS0xMCksIEludFNsaWRlcih2YWx1ZT0wLCBkZXNjcmlwdGlvbj3igKY=
# <function engine.widgets.update>

# %%
engine.widgets.distribution()
# Out:
# aW50ZXJhY3RpdmUoY2hpbGRyZW49KEludFNsaWRlcih2YWx1ZT0wLCBkZXNjcmlwdGlvbj11J2RleCcsIG1heD0xMCwgbWluPS0xMCksIEludFNsaWRlcih2YWx1ZT0wLCBkZXNjcmlwdGlvbj3igKY=
# <function engine.widgets.update>
